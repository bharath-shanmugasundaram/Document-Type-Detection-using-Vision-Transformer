# %%
import os
from pdf2image import convert_from_path
from tqdm import tqdm


PDF_ROOT = "/Users/bhara-zstch1566/Projects/CRM DI/Document Type Detection/Data Cleaner/New"
IMG_ROOT = "/Users/bhara-zstch1566/Projects/CRM DI/Document Type Detection/Data Cleaner/form2"

DPI = 300
IMAGE_FORMAT = "JPEG"

def convert_pdf(pdf_path, out_dir):
    pdf_name = os.path.splitext(os.path.basename(pdf_path))[0]

    try:
        pages = convert_from_path(
            pdf_path,
            dpi=DPI,
            thread_count=4  # speedup
        )

        for i, page in enumerate(pages):
            img_name = f"{pdf_name}_page_{i+1}.jpg"
            img_path = os.path.join(out_dir, img_name)
            page.save(img_path, IMAGE_FORMAT)

    except Exception as e:
        print(f"❌ Failed: {pdf_path}")
        print(e)


for root, _, files in os.walk(PDF_ROOT):
    for file in tqdm(files, desc="Processing PDFs"):
        if not file.lower().endswith(".pdf"):
            continue

        pdf_path = os.path.join(root, file)

        rel_path = os.path.relpath(root, PDF_ROOT)
        out_dir = os.path.join(IMG_ROOT, rel_path)

        os.makedirs(out_dir, exist_ok=True)

        convert_pdf(pdf_path, out_dir)

print("✅ ALL PDFs converted successfully")
# Out:
# Processing PDFs:  53%|█████▎    | 63/118 [00:28<00:47,  1.15it/s]
# ❌ Failed: /Users/bhara-zstch1566/Projects/CRM DI/Document Type Detection/Data Cleaner/New/Form-18.pdf
# Image size (186095000 pixels) exceeds limit of 178956970 pixels, could be decompression bomb DOS attack.
# Processing PDFs: 100%|██████████| 118/118 [00:55<00:00,  2.12it/s]
# ✅ ALL PDFs converted successfully

# %%
from pdf2image import convert_from_path

pages = convert_from_path(
    "/Users/bhara-zstch1566/Projects/CRM DI/Document Type Detection/Data Cleaner/Insurence Policy/20. Tax benefits due to health insurance.pdf",
    dpi=300
)

print(len(pages))
pages[0].show()
# Out:
# 14

# %%
import os

len(os.listdir("/Users/bhara-zstch1566/Projects/CRM DI/Document Type Detection/Data Cleaner/image"))
# Out:
# 3526

# %%
# for i in os.listdir("/Users/bhara-zstch1566/Projects/CRM DI/Document Type Detection/Dataset/Insurance_Policy"):
    # print
print(sorted(os.listdir("/Users/bhara-zstch1566/Projects/CRM DI/Document Type Detection/Dataset/Insurance_Policy"),reverse=True))
# Out:
# ['specification_9995.png', 'specification_9992.png', 'specification_9980.png', 'specification_998.png', 'specification_9978.png', 'specification_9957.png', 'specification_9955.png', 'specification_9951.png', 'specification_9945.png', 'specification_9942.png', 'specification_993.png', 'specification_9927.png', 'specification_9921.png', 'specification_9918.png', 'specification_9909.png', 'specification_9885.png', 'specification_9877.png', 'specification_9868.png', 'specification_9849.png', 'specification_9842.png', 'specification_984.png', 'specification_9834.png', 'specification_9832.png', 'specification_9831.png', 'specification_983.png', 'specification_9826.png', 'specification_9821.png', 'specification_9819.png', 'specification_9818.png', 'specification_9809.png', 'specification_9808.png', 'specification_979.png', 'specification_9789.png', 'specification_9776.png', 'specification_9760.png', 'specification_9759.png', 'specification_9748.png', 'specification_9739.png', 'specification
# ...

# %%
path = "/Users/bhara-zstch1566/Projects/CRM DI/Document Type Detection/Insurance_Policy"
# lis = sorted(os.listdir("/Users/bhara-zstch1566/Projects/CRM DI/Document Type Detection/Insurance_Policy"),reverse=True)

# for i in range(1,3526):
#     os.remove(os.path.join(path,lis[i]))

print(len(os.listdir("/Users/bhara-zstch1566/Projects/CRM DI/Document Type Detection/Dataset/Insurance_Policy")))
# Out:
# 9869

# %%
path = "/Users/bhara-zstch1566/Projects/CRM DI/Document Type Detection/Dataset/Insurance_Policy"
lis = os.listdir(path)
app = os.listdir("/Users/bhara-zstch1566/Projects/CRM DI/Document Type Detection/Insurance_Policy")
app.sort()
for i in range(3395,10001):
    os.

# %%
lis
# Out:
# ['form_16086.png',
#  'questionnaire_6281.png',
#  'form_7154.png',
#  'form_13840.png',
#  'form_148.png',
#  'form_1525.png',
#  'questionnaire_1288.png',
#  'form_5743.png',
#  'form_18915.png',
#  'questionnaire_15800.png',
#  'form_2038.png',
#  'form_18901.png',
#  'form_3326.png',
#  'form_12592.png',
#  'form_8273.png',
#  'form_7140.png',
#  'form_1531.png',
#  'form_16092.png',
#  'questionnaire_4482.png',
#  'form_36.png',
#  'form_6510.png',
#  'questionnaire_8290.png',
#  'form_18097.png',
#  'questionnaire_15182.png',
#  'form_2776.png',
#  'questionnaire_2965.png',
#  'form_6276.png',
#  'questionnaire_11482.png',
#  'form_13868.png',
#  'form_4313.png',
#  'form_18083.png',
#  'questionnaire_10005.png',
#  'form_12223.png',
#  'form_835.png',
#  'questionnaire_19747.png',
#  'form_14652.png',
#  'form_18068.png',
#  'questionnaire_5993.png',
#  'form_3497.png',
#  'form_19376.png',
#  'questionnaire_14263.png',
#  'form_16045.png',
#  'questionnaire_4455.png',
# ...

# %%
path = "/Users/bhara-zstch1566/Projects/CRM DI/Document Type Detection/Dataset/Gov Forms"
lis=sorted(os.listdir(path),reverse=True)

end = len(os.listdir("/Users/bhara-zstch1566/Projects/CRM DI/Document Type Detection/Data Cleaner/Forms"))

# for i in range(end):
#     os.remove(os.path.join(path,lis[i]))
print(len(os.listdir(path)))
# Out:
# 10002
